# %%
#Problem 5

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return 3*x + y

# %%
plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
int = f(x,y).integrate(x,-2,-1).integrate(y,0,5)

# %%
int
# Out:
# -10

# %% [markdown]
# ---

# %%
#Problem 13

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x + y^2

# %%
plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
int = f(x,y).integrate(y,0,x).integrate(x,0,2)

# %%
int
# Out:
# 4

# %% [markdown]
# ---

# %%
#Problem 17

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x^2 + 1/3*x*y

# %%
plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
int = f(x,y).integrate(x,0,1).integrate(y,0,2)

# %%
int
# Out:
# 1

# %% [markdown]
# ---

# %%
#Problem 21

# %%
x = var('x')

# %%
y = var('y')

# %%
z = var('z')

# %%
def f(x, y, z): return 2*x + 3*y -z

# %%
int = f(x,y,z).integrate(x,-1,2).integrate(y,1,3).integrate(z,0,1)

# %%
int
# Out:
# 39
